# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
broken_df = pd.read_csv('bikes.csv', sep='\t', comment='#', encoding='latin1')

# %%
broken_df
# Out:
#     Date;Berri 1;Brébeuf (données non disponibles);Côte-Sainte-Catherine;Maisonneuve 1;Maisonneuve 2;du Parc;Pierre-Dupuy;Rachel1;St-Urbain (données non disponibles)
# 0                     01/01/2012;35;;0;38;51;26;10;16;
# 1                     02/01/2012;83;;1;68;153;53;6;43;
# 2                   03/01/2012;135;;2;104;248;89;3;58;
# 3                  04/01/2012;144;;1;116;318;111;8;61;
# 4                  05/01/2012;197;;2;124;330;97;13;95;
# ..                                                 ...
# 317                                            Pricing
# 318                                                API
# 319                                           Training
# 320                                               Blog
# 321                                              About
#
# [322 rows x 1 columns]

# %%
# Look at the first 3 rows
broken_df[:3]
# Out:
#   Date;Berri 1;Brébeuf (données non disponibles);Côte-Sainte-Catherine;Maisonneuve 1;Maisonneuve 2;du Parc;Pierre-Dupuy;Rachel1;St-Urbain (données non disponibles)
# 0                   01/01/2012;35;;0;38;51;26;10;16;
# 1                   02/01/2012;83;;1;68;153;53;6;43;
# 2                 03/01/2012;135;;2;104;248;89;3;58;

# %%
fixed_df = pd.read_csv('bikes.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
fixed_df[:3]
# Out:
#             Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  \
# Date
# 01/01/2012     35.0                                NaN                    0.0
# 02/01/2012     83.0                                NaN                    1.0
# 03/01/2012    135.0                                NaN                    2.0
#
#             Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  \
# Date
# 01/01/2012           38.0           51.0     26.0          10.0     16.0
# 02/01/2012           68.0          153.0     53.0           6.0     43.0
# 03/01/2012          104.0          248.0     89.0           3.0     58.0
#
#             St-Urbain (données non disponibles)
# Date
# 01/01/2012                                  NaN
# 02/01/2012                                  NaN
# 03/01/2012                                  NaN

# %%
fixed_df['Berri 1']
# Out:
# Date
# 01/01/2012     35.0
# 02/01/2012     83.0
# 03/01/2012    135.0
# 04/01/2012    144.0
# 05/01/2012    197.0
#               ...
# Pricing         NaN
# API             NaN
# Training        NaN
# Blog            NaN
# About           NaN
# Name: Berri 1, Length: 322, dtype: float64

# %%
fixed_df['Berri 1'].plot()

# %%
fixed_df.plot(figsize=(15, 10))

# %%
df = pd.read_csv('bikes.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
df['Berri 1'].plot()
